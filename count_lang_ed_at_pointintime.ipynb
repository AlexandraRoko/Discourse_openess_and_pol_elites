# %%
import pandas as pd

# %%
creation_date_df = pd.read_csv("/Users/alexandrarottenkolber/Documents/02_Hertie_School/Master thesis/Master_Thesis_Hertie/data_analysis/01_data/Wikipedia/output/history_lang_eds_df_complete.csv").drop(columns = ["Unnamed: 0"])

# %%
creation_date_df.head()
# Out:
#   wikidataid    creation_date_lang language     wikititle  creation_year_lang  \
# 0      Q2514  2018-06-25T09:40:49Z       af  Willy_Brandt                2018
# 1      Q2514  2013-12-18T13:58:41Z      als  Willy_Brandt                2013
# 2      Q2514  2009-10-08T13:55:56Z       an  Willy_Brandt                2009
# 3      Q2514  2007-07-08T21:03:22Z       ar   ويلي_براندت                2007
# 4      Q2514  2020-02-12T01:49:31Z      arz   فيلى_براندت                2020
#
#    creation_month_lang  creation_day_lang
# 0                    6                 25
# 1                   12                 18
# 2                   10                  8
# 3                    7                  8
# 4                    2                 12

# %%
creation_date_df[creation_date_df["wikidataid"] == "Q18169686"].sort_values(by = ["creation_year_lang", "creation_month_lang", "creation_day_lang"])
# Out:
#       wikidataid    creation_date_lang language       wikititle  \
# 10500  Q18169686  2014-09-19T21:04:28Z       de    Paul_Ziemiak
# 10501  Q18169686  2018-03-20T17:55:44Z       en    Paul_Ziemiak
# 10503  Q18169686  2018-12-08T14:59:18Z       fr    Paul_Ziemiak
# 10504  Q18169686  2018-12-08T15:39:47Z      hsb    Paul_Ziemiak
# 10508  Q18169686  2018-12-08T09:33:23Z       no    Paul_Ziemiak
# 10509  Q18169686  2018-12-11T09:43:28Z       pl    Paul_Ziemiak
# 10507  Q18169686  2019-04-22T08:37:23Z       la  Paulus_Ziemiak
# 10499  Q18169686  2020-02-17T02:47:36Z       cv     Пауль_Цимяк
# 10506  Q18169686  2020-03-24T12:43:39Z       ie    Paul_Ziemiak
# 10505  Q18169686  2020-12-22T08:12:30Z       id    Paul_Ziemiak
# 10498  Q18169686  2021-09-18T16:01:10Z       cs    Paul_Ziemiak
# 10497  Q18169686  2022-01-03T00:40:52Z      arz      بول_زيمياك
# 10502  Q18169686  2022-01-22T14:29:25Z       es    Paul_Ziemiak
#
#        creation_year_lang  creation_month_lang  creation_day_lang
# ...

# %%
years = list((creation_date_df["creation_year_lang"]).unique())
months = list((creation_date_df["creation_month_lang"]).unique())
days = list((creation_date_df["creation_day_lang"]).unique())
IDs = list((creation_date_df["wikidataid"]).unique())

# %%
ID_ls = []
years_ls = []
no_lan_eds_ls = []
languages_ls = []

for ID in IDs: 
    years = list(creation_date_df[creation_date_df["wikidataid"] == ID]["creation_year_lang"])
    for year in years: 
        no_lang_eds = len(creation_date_df[(creation_date_df["wikidataid"] == ID) & (creation_date_df["creation_year_lang"] <= year)])
        languages = list(creation_date_df[(creation_date_df["wikidataid"] == ID) & (creation_date_df["creation_year_lang"] <= year)]["language"].unique())
        
        
        ID_ls.append(ID)
        years_ls.append(year)
        no_lan_eds_ls.append(no_lang_eds)
        languages_ls.append(languages)
        
res_df = pd.DataFrame()
res_df["wikidataid"] = ID_ls
res_df["year"] = years_ls
res_df["no_lang_eds"] = no_lan_eds_ls
res_df["languages"] = languages_ls

# %%
creation_date_df[(creation_date_df["wikidataid"] == "Q18169686") & (creation_date_df["creation_year_lang"] <= 2018)]
# Out:
#       wikidataid    creation_date_lang language     wikititle  \
# 10500  Q18169686  2014-09-19T21:04:28Z       de  Paul_Ziemiak
# 10501  Q18169686  2018-03-20T17:55:44Z       en  Paul_Ziemiak
# 10503  Q18169686  2018-12-08T14:59:18Z       fr  Paul_Ziemiak
# 10504  Q18169686  2018-12-08T15:39:47Z      hsb  Paul_Ziemiak
# 10508  Q18169686  2018-12-08T09:33:23Z       no  Paul_Ziemiak
# 10509  Q18169686  2018-12-11T09:43:28Z       pl  Paul_Ziemiak
#
#        creation_year_lang  creation_month_lang  creation_day_lang
# 10500                2014                    9                 19
# 10501                2018                    3                 20
# 10503                2018                   12                  8
# 10504                2018                   12                  8
# 10508                2018                   12                  8
# 10509                2018                   12                 11

# %%
#creation_date_df[(creation_date_df["wikidataid"] == "Q18169686") & (creation_date_df["creation_year_lang"] <= 2018)]

# %%
len(creation_date_df[(creation_date_df["wikidataid"] == "Q18169686") & (creation_date_df["creation_year_lang"] <= 2018)])
# Out:
# 6

# %%
list(creation_date_df[(creation_date_df["wikidataid"] == "Q18169686") & (creation_date_df["creation_year_lang"] <= 2018)]["language"])
# Out:
# ['de', 'en', 'fr', 'hsb', 'no', 'pl']

# %%
res_df
# Out:
#       wikidataid  year  no_lang_eds  \
# 0          Q2514  2018           89
# 1          Q2514  2013           75
# 2          Q2514  2009           58
# 3          Q2514  2007           46
# 4          Q2514  2020           93
# ...          ...   ...          ...
# 10505  Q18169686  2020           10
# 10506  Q18169686  2020           10
# 10507  Q18169686  2019            7
# 10508  Q18169686  2018            6
# 10509  Q18169686  2018            6
#
#                                                languages
# 0      [af, als, an, ar, ast, azb, az, bar, be-tarask...
# 1      [als, an, ar, bar, be-tarask, be, bg, br, bs, ...
# 2      [an, ar, be, bg, br, bs, ca, cs, cy, da, de, d...
# 3      [ar, bg, br, bs, ca, cs, da, de, el, en, eo, e...
# 4      [af, als, an, ar, arz, ast, azb, az, bar, be-t...
# ...                                                  ...
# 10505          [cv, de, en, fr, hsb, id, ie, la, no, pl]
# 10506          [cv, de, en, fr, hsb, id, ie, la, no, pl]
# ...

# %%
creation_date_df[(creation_date_df["wikidataid"] == "Q2514") & (creation_date_df["creation_year_lang"] <= 2018)]
# Out:
#    wikidataid    creation_date_lang language     wikititle  \
# 0       Q2514  2018-06-25T09:40:49Z       af  Willy_Brandt
# 1       Q2514  2013-12-18T13:58:41Z      als  Willy_Brandt
# 2       Q2514  2009-10-08T13:55:56Z       an  Willy_Brandt
# 3       Q2514  2007-07-08T21:03:22Z       ar   ويلي_براندت
# 5       Q2514  2018-06-17T17:54:33Z      ast  Willy_Brandt
# ..        ...                   ...      ...           ...
# 89      Q2514  2009-04-19T13:50:04Z       vi  Willy_Brandt
# 90      Q2514  2010-03-29T06:47:31Z      war  Willy_Brandt
# 92      Q2514  2010-04-25T05:48:36Z       yo  Willy_Brandt
# 93      Q2514  2016-10-26T08:10:46Z   zh-yue         威利布蘭特
# 94      Q2514  2005-02-03T03:08:27Z       zh        维利·勃兰特
#
#     creation_year_lang  creation_month_lang  creation_day_lang
# 0                 2018                    6                 25
# 1                 2013                   12                 18
# 2                 2009                   10                  8
# ...

# %%
res_df.head()
# Out:
#   wikidataid  year  no_lang_eds  \
# 0      Q2514  2018           89
# 1      Q2514  2013           75
# 2      Q2514  2009           58
# 3      Q2514  2007           46
# 4      Q2514  2020           93
#
#                                            languages
# 0  [af, als, an, ar, ast, azb, az, bar, be-tarask...
# 1  [als, an, ar, bar, be-tarask, be, bg, br, bs, ...
# 2  [an, ar, be, bg, br, bs, ca, cs, cy, da, de, d...
# 3  [ar, bg, br, bs, ca, cs, da, de, el, en, eo, e...
# 4  [af, als, an, ar, arz, ast, azb, az, bar, be-t...

# %%
res_df[res_df["wikidataid"] == "Q2514"].sort_values("year")
# Out:
#    wikidataid  year  no_lang_eds  \
# 23      Q2514  2002            2
# 19      Q2514  2002            2
# 80      Q2514  2003            6
# 25      Q2514  2003            6
# 45      Q2514  2003            6
# ..        ...   ...          ...
# 20      Q2514  2020           93
# 4       Q2514  2020           93
# 91      Q2514  2020           93
# 74      Q2514  2021           95
# 65      Q2514  2021           95
#
#                                             languages
# 23                                           [de, en]
# 19                                           [de, en]
# 80                           [de, en, es, ja, nl, sv]
# 25                           [de, en, es, ja, nl, sv]
# 45                           [de, en, es, ja, nl, sv]
# ..                                                ...
# 20  [af, als, an, ar, arz, ast, azb, az, bar, be-t...
# 4   [af, als, an, ar, arz, ast, azb, az, bar, be-t...
# 91  [af, als, an, ar, arz, ast, azb, az, bar, be-t...
# ...

# %%
creation_date_df.head()
# Out:
#   wikidataid    creation_date_lang language     wikititle  creation_year_lang  \
# 0      Q2514  2018-06-25T09:40:49Z       af  Willy_Brandt                2018
# 1      Q2514  2013-12-18T13:58:41Z      als  Willy_Brandt                2013
# 2      Q2514  2009-10-08T13:55:56Z       an  Willy_Brandt                2009
# 3      Q2514  2007-07-08T21:03:22Z       ar   ويلي_براندت                2007
# 4      Q2514  2020-02-12T01:49:31Z      arz   فيلى_براندت                2020
#
#    creation_month_lang  creation_day_lang
# 0                    6                 25
# 1                   12                 18
# 2                   10                  8
# 3                    7                  8
# 4                    2                 12

# %%
per_year = creation_date_df.groupby(by = ["wikidataid", "creation_year_lang"]).nunique().drop(columns = ["creation_month_lang", "creation_day_lang", "wikititle", "creation_date_lang"]).reset_index()
per_year = per_year.rename(columns = {"language" : "no_languages_created", "creation_year_lang" : "year"})
per_year.head(2)
# Out:
#   wikidataid  year  no_languages_created
# 0   Q1000195  2007                     1
# 1   Q1000195  2020                     1

# %%
per_year[per_year["wikidataid"] == "Q2514"].head(3)
# Out:
#      wikidataid  year  no_languages_created
# 3970      Q2514  2002                     2
# 3971      Q2514  2003                     4
# 3972      Q2514  2004                     6

# %%
per_year['cum_sum_no_languages'] = per_year[["wikidataid", "no_languages_created"]].groupby(by = ["wikidataid"]).cumsum()

# %%
per_year[per_year["wikidataid"] == "Q2514"]
# Out:
#      wikidataid  year  no_languages_created  cum_sum_no_languages
# 3970      Q2514  2002                     2                     2
# 3971      Q2514  2003                     4                     6
# 3972      Q2514  2004                     6                    12
# 3973      Q2514  2005                    14                    26
# 3974      Q2514  2006                    12                    38
# 3975      Q2514  2007                     8                    46
# 3976      Q2514  2008                     4                    50
# 3977      Q2514  2009                     8                    58
# 3978      Q2514  2010                     7                    65
# 3979      Q2514  2011                     3                    68
# 3980      Q2514  2012                     2                    70
# 3981      Q2514  2013                     5                    75
# 3982      Q2514  2015                     3                    78
# ...

# %%
len(per_year["wikidataid"].unique())
# Out:
# 2187

# %%
per_year[per_year["wikidataid"] == per_year["wikidataid"][3]]
# Out:
#   wikidataid  year  no_languages_created  cum_sum_no_languages
# 2    Q100218  2005                     1                     1
# 3    Q100218  2006                     1                     2
# 4    Q100218  2015                     1                     3
# 5    Q100218  2020                     1                     4

# %%
years = sorted([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])


WIKIDATAID = []
YEAR = []
NO_LANG_CREATED = []
CUM_SUM_LANG = []

for ID in set(per_year["wikidataid"]): 
    years_ID = sorted(per_year["year"][per_year["wikidataid"] == ID])
    for year in years: 
        if year in years_ID: 
            
            WIKIDATAID.append(ID)
            YEAR.append(year)
            NO_LANG_CREATED.append(list(per_year["no_languages_created"][(per_year["wikidataid"] == ID) & (per_year["year"] == year)])[0])
            CUM_SUM_LANG.append(list(per_year["cum_sum_no_languages"][(per_year["wikidataid"] == ID) & (per_year["year"] == year)])[0])
            
        elif year not in years_ID: 
            temp_years = sorted(per_year["year"][per_year["wikidataid"] == ID])
            temp_years.append(year)
            temp_years = sorted(temp_years)
            idx_ = temp_years.index(year)
            
            if idx_ >= 1:
                cum_sum_lang = list(per_year["cum_sum_no_languages"][(per_year["wikidataid"] == ID) & (per_year["year"] == temp_years[idx_-1])])[0]
            else: 
                cum_sum_lang = 0
            
            
            WIKIDATAID.append(ID)
            YEAR.append(year)
            NO_LANG_CREATED.append(0)
            CUM_SUM_LANG.append(cum_sum_lang)
        
        else: 
            print(ID, year)

# %%
len(WIKIDATAID), len(YEAR), len(NO_LANG_CREATED), len(CUM_SUM_LANG),
# Out:
# (43740, 43740, 43740, 43740)

# %%
#years

# %%
per_year[per_year["wikidataid"] == "Q1000195"]
# Out:
#   wikidataid  year  no_languages_created  cum_sum_no_languages
# 0   Q1000195  2007                     1                     1
# 1   Q1000195  2020                     1                     2

# %%
years_ID = sorted(per_year["year"][per_year["wikidataid"] == "Q1000195"])
years_ID
# Out:
# [2007, 2020]

# %%
temp_years = years_ID
temp_years.append(2021)
temp_years = sorted(temp_years)
idx_ = temp_years.index(2021)

if idx_ >= 1:
    cum_sum_lang = list(per_year["cum_sum_no_languages"][(per_year["wikidataid"] == ID) & (per_year["year"] == temp_years[idx_-1])])[0]
else: 
    cum_sum_lang = 0

# %%
cum_sum_lang
# Out:
# 2

# %%
temp_years
# Out:
# [2007, 2020, 2021]

# %%
full_results_per_year = pd.DataFrame()

# %%
full_results_per_year["wikidataid"] = WIKIDATAID
full_results_per_year["year"] = YEAR
full_results_per_year["no_languages_created"] = NO_LANG_CREATED
full_results_per_year["cum_sum_no_languages"] = CUM_SUM_LANG

# %%
full_results_per_year[full_results_per_year["wikidataid"] == "Q100218"]
# Out:
#       wikidataid  year  no_languages_created  cum_sum_no_languages
# 23960    Q100218  2002                     0                     0
# 23961    Q100218  2003                     0                     0
# 23962    Q100218  2004                     0                     0
# 23963    Q100218  2005                     1                     1
# 23964    Q100218  2006                     1                     2
# 23965    Q100218  2007                     0                     2
# 23966    Q100218  2008                     0                     2
# 23967    Q100218  2009                     0                     2
# 23968    Q100218  2010                     0                     2
# 23969    Q100218  2011                     0                     2
# 23970    Q100218  2012                     0                     2
# 23971    Q100218  2013                     0                     2
# 23972    Q100218  2014                     0                     2
# ...

# %%
full_results_per_year.to_csv("/Users/alexandrarottenkolber/Documents/02_Hertie_School/Master thesis/Master_Thesis_Hertie/data_analysis/01_data/Wikipedia/output/history_nolanguages_counted_all_years.csv")
